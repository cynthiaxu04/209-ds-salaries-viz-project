# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/cynthiaxu/Documents/MIDS/03_2023 Fall/209 Data Visualization/209-ds-salaries-viz-project/code'

# %%
root = '/Users/cynthiaxu/Documents/MIDS/03_2023 Fall/209 Data Visualization/209-ds-salaries-viz-project/'
folder = 'data'

data_path = os.path.join(root, folder)
data_path
# Out:
# '/Users/cynthiaxu/Documents/MIDS/03_2023 Fall/209 Data Visualization/209-ds-salaries-viz-project/data'

# %%
os.path.isdir(data_path)
# Out:
# True

# %%
data_files = os.listdir(data_path)
data_files
# Out:
# ['ds_salaries.csv',
#  'Data Science Salary 2021 to 2023.csv',
#  'README.md',
#  'Data Science Jobs Salaries.csv',
#  '.ipynb_checkpoints',
#  'data_cleaned_2021.csv']

# %%
data_dict = {}
for i in data_files:
    if '.csv' in i:
        df = pd.read_csv(os.path.join(data_path, i))
        name = i[:-4]
        data_dict[name] = df

# %%
keys = list(data_dict.keys())
keys
# Out:
# ['ds_salaries',
#  'Data Science Salary 2021 to 2023',
#  'Data Science Jobs Salaries',
#  'data_cleaned_2021']

# %%
df1 = data_dict[keys[0]]
df1
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          607 non-null    int64
#  1   work_year           607 non-null    int64
#  2   experience_level    607 non-null    object
#  3   employment_type     607 non-null    object
#  4   job_title           607 non-null    object
#  5   salary              607 non-null    int64
#  6   salary_currency     607 non-null    object
#  7   salary_in_usd       607 non-null    int64
#  8   employee_residence  607 non-null    object
#  9   remote_ratio        607 non-null    int64
#  10  company_location    607 non-null    object
#  11  company_size        607 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 57.0+ KB

# %%
df2 = data_dict[keys[1]]
df2
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3761 entries, 0 to 3760
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         3761 non-null   int64
#  1   experience_level  3761 non-null   object
#  2   employment_type   3761 non-null   object
#  3   job_title         3761 non-null   object
#  4   salary            3761 non-null   int64
#  5   salary_currency   3761 non-null   object
#  6   salary_in_usd     3761 non-null   int64
#  7   company_location  3761 non-null   object
#  8   company_size      3761 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 264.6+ KB

# %%
df3 = data_dict[keys[2]]
df3
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0       2021e               EN              FT    Data Science Consultant
# 1        2020               SE              FT             Data Scientist
# 2       2021e               EX              FT       Head of Data Science
# 3       2021e               EX              FT               Head of Data
# 4       2021e               EN              FT  Machine Learning Engineer
# ..        ...              ...             ...                        ...
# 240      2020               SE              FT             Data Scientist
# 241     2021e               MI              FT   Principal Data Scientist
# 242      2020               EN              FT             Data Scientist
# 243      2020               EN              CT      Business Data Analyst
# 244     2021e               SE              FT       Data Science Manager
#
#       salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 245 entries, 0 to 244
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           245 non-null    object
#  1   experience_level    245 non-null    object
#  2   employment_type     245 non-null    object
#  3   job_title           245 non-null    object
#  4   salary              245 non-null    int64
#  5   salary_currency     245 non-null    object
#  6   salary_in_usd       245 non-null    int64
#  7   employee_residence  245 non-null    object
#  8   remote_ratio        245 non-null    int64
#  9   company_location    245 non-null    object
#  10  company_size        245 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 21.2+ KB

# %%
df3['work_year'].unique()
# Out:
# array(['2021e', '2020'], dtype=object)

# %%
df1['work_year'].unique()
# Out:
# array([2020, 2021, 2022])

# %%
df4 = data_dict[keys[3]]
df4
# Out:
#      index                                          Job Title  \
# 0        0                                     Data Scientist
# 1        1                          Healthcare Data Scientist
# 2        2                                     Data Scientist
# 3        3                                     Data Scientist
# 4        4                                     Data Scientist
# ..     ...                                                ...
# 737    950           Sr Scientist, Immuno-Oncology - Oncology
# 738    951                               Senior Data Engineer
# 739    952  Project Scientist - Auton Lab, Robotics Institute
# 740    953                               Data Science Manager
# 741    955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               742 non-null    int64
#  1   Job Title           742 non-null    object
#  2   Salary Estimate     742 non-null    object
#  3   Job Description     742 non-null    object
#  4   Rating              742 non-null    float64
#  5   Company Name        742 non-null    object
#  6   Location            742 non-null    object
#  7   Headquarters        742 non-null    object
#  8   Size                742 non-null    object
#  9   Founded             742 non-null    int64
#  10  Type of ownership   742 non-null    object
#  11  Industry            742 non-null    object
#  12  Sector              742 non-null    object
#  13  Revenue             742 non-null    object
#  14  Competitors         742 non-null    object
# ...

# %%
df2['work_year'].unique()
# Out:
# array([2023, 2022, 2021, 2020])

# %%
df1_2021 = df1.loc[df1['work_year']==2021]

# %%
df2_2021 = df2.loc[df2['work_year']==2021]

# %%
df1_2021
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 72           72       2021               EN              FT
# 73           73       2021               EX              FT
# 74           74       2021               EX              FT
# 75           75       2021               SE              FT
# 76           76       2021               MI              FT
# ..          ...        ...              ...             ...
# 284         284       2021               MI              FT
# 285         285       2021               SE              FT
# 286         286       2021               SE              FT
# 287         287       2021               MI              FT
# 288         288       2021               MI              FT
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 72          Research Scientist    60000             GBP          82528
# 73             BI Data Analyst   150000             USD         150000
# ...

# %%
df2_2021
# Out:
#       work_year experience_level employment_type  \
# 3455       2021               EN              FT
# 3456       2021               EN              FT
# 3457       2021               EN              FT
# 3458       2021               EN              FT
# 3459       2021               EN              FT
# ...         ...              ...             ...
# 3680       2021               SE              FT
# 3681       2021               SE              FT
# 3682       2021               SE              FT
# 3683       2021               SE              FT
# 3684       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 3455             Marketing Data Engineer    90000             SGD
# 3456       3D Computer Vision Researcher    20000             USD
# 3457                  Power BI Developer   400000             INR
# 3458                        Data Analyst    56000             AUD
# ...

# %%
int_df = pd.merge(df1_2021, df2_2021, how='inner', on=['experience_level', 'salary_in_usd', 'company_location', 'company_size', 'employment_type', 'job_title'])
int_df
# Out:
#      Unnamed: 0  work_year_x experience_level employment_type  \
# 0            72         2021               EN              FT
# 1            73         2021               EX              FT
# 2            74         2021               EX              FT
# 3            75         2021               SE              FT
# 4            76         2021               MI              FT
# ..          ...          ...              ...             ...
# 207         284         2021               MI              FT
# 208         285         2021               SE              FT
# 209         286         2021               SE              FT
# 210         287         2021               MI              FT
# 211         288         2021               MI              FT
#
#                      job_title  salary_x salary_currency_x  salary_in_usd  \
# 0           Research Scientist     60000               GBP          82528
# ...

# %%
df2.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
#overlapping columns
on_columns = [i for i in df1.columns if i in df2.columns]
on_columns
# Out:
# ['work_year',
#  'experience_level',
#  'employment_type',
#  'job_title',
#  'salary',
#  'salary_currency',
#  'salary_in_usd',
#  'company_location',
#  'company_size']

# %%
#drop EX experience_level label from both datasets since there is discrepancy in how they're described; keep only overlapping columns
df1_new = df1.loc[df1['experience_level'] != 'EX', on_columns]
df1_new
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df2_new = df2.loc[df2['experience_level'] != 'EX', on_columns]
df2_new
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
# overlap = pd.merge(df1_new, df2_new, how='inner', on=on_columns)
# overlap

# %%
# df_2023_only = df2_new.loc[df2_new['work_year']==2023]
# df_2023_only

# %%
len(df1_new)
# Out:
# 581

# %%
len(df2_new)
# Out:
# 3647

# %%
# len(overlap)

# %%
#concat everything together
all_df = pd.concat([df1_new, df2_new])
len(all_df)
# Out:
# 4228

# %%
final_df = all_df.drop_duplicates(subset=on_columns, keep='first').reset_index(drop=True)
len(final_df)
# Out:
# 2392

# %%
final_df
# Out:
#       work_year experience_level employment_type                   job_title  \
# 0          2020               MI              FT              Data Scientist
# 1          2020               SE              FT  Machine Learning Scientist
# 2          2020               SE              FT           Big Data Engineer
# 3          2020               MI              FT        Product Data Analyst
# 4          2020               SE              FT   Machine Learning Engineer
# ...         ...              ...             ...                         ...
# 2387       2021               SE              FT               Data Engineer
# 2388       2020               EN              FT               Data Engineer
# 2389       2020               EN              FT                Data Analyst
# 2390       2020               MI              FT       Business Data Analyst
# 2391       2020               MI              FT               Data Engineer
#
# ...

# %%
final_df.to_csv(os.path.join(root, 'cleaned_data', 'ds_salaries_2020-2023.csv'), index=False)
